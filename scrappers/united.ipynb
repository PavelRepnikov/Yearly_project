# %%
import pandas as pd


df1 = pd.read_excel('parsed_news_kommersant_archive.xlsx')
df2 = pd.read_excel('parsed_news_lenta_archive.xlsx')
df3 = pd.read_excel('parsed_news_mkru_archive.xlsx')

df_combined = pd.concat([df1, df2, df3], ignore_index=True)

df_combined.to_excel('parsed_news.xlsx', index=False)

# %%
df_combined
# Out:
#         Unnamed: 0                                                url  \
# 0                0               https://www.kommersant.ru/doc/973901
# 1                1              https://www.kommersant.ru/doc/2200895
# 2                2              https://www.kommersant.ru/doc/3859122
# 3                3              https://www.kommersant.ru/doc/5347136
# 4                4              https://www.kommersant.ru/doc/1171617
# ...            ...                                                ...
# 982408       24598  https://www.mk.ru/incident/2018/02/17/11letnya...
# 982409       24599  https://www.mk.ru/politics/2013/05/17/855954-p...
# 982410       24600  https://www.mk.ru/economics/2013/03/27/832629-...
# 982411       24601  https://www.mk.ru/politics/2018/07/17/mid-esto...
# 982412       24602  https://www.mk.ru/politics/2014/09/13/yacenyuk...
#
#               date and time                              tag  \
# 0         22.04.2004, 17:39                              Мир
# ...
